# %%
import urllib
import numpy
url = 'http://portal.opendata.dk/api/action/datastore_search?resource_id=bc2e23a0-08a7-4c84-9c50-8b4e22537a65'
fileobj = urllib.urlopen(url)
json.loads(fileobj.read())["result"]
# Out:
# {u'_links': {u'next': u'/api/action/datastore_search?offset=100&resource_id=bc2e23a0-08a7-4c84-9c50-8b4e22537a65',
#   u'start': u'/api/action/datastore_search?resource_id=bc2e23a0-08a7-4c84-9c50-8b4e22537a65'},
#  u'fields': [{u'id': u'_id', u'type': u'int4'},
#   {u'id': u'AAR', u'type': u'numeric'},
#   {u'id': u'BYDEL', u'type': u'numeric'},
#   {u'id': u'ALDERSKAT', u'type': u'numeric'},
#   {u'id': u'IETYPE', u'type': u'numeric'},
#   {u'id': u'SOC_GRUPPE', u'type': u'numeric'},
#   {u'id': u'SOCSTIL', u'type': u'numeric'},
#   {u'id': u'PERSONER', u'type': u'numeric'}],
#  u'records': [{u'AAR': u'2013',
#    u'ALDERSKAT': u'1',
#    u'BYDEL': u'1',
#    u'IETYPE': u'1',
#    u'PERSONER': u'11',
#    u'SOCSTIL': u'132',
#    u'SOC_GRUPPE': u'1',
#    u'_id': 1},
#   {u'AAR': u'2013',
#    u'ALDERSKAT': u'1',
#    u'BYDEL': u'1',
#    u'IETYPE': u'1',
#    u'PERSONER': u'4',
#    u'SOCSTIL': u'133',
#    u'SOC_GRUPPE': u'1',
#    u'_id': 2},
#   {u'AAR': u'2013',
# ...

# %%
url = 'http://portal.opendata.dk/api/action/datastore_search?resource_id=d344488b-96d3-42ab-a8ce-1113795fee8c'
fileobj = urllib.urlopen(url)
json.loads(fileobj.read())["result"]
# Out:
# {u'_links': {u'next': u'/api/action/datastore_search?offset=100&resource_id=d344488b-96d3-42ab-a8ce-1113795fee8c',
#   u'start': u'/api/action/datastore_search?resource_id=d344488b-96d3-42ab-a8ce-1113795fee8c'},
#  u'fields': [{u'id': u'_id', u'type': u'int4'},
#   {u'id': u'AAR', u'type': u'numeric'},
#   {u'id': u'BYDEL', u'type': u'numeric'},
#   {u'id': u'HUSTYP', u'type': u'numeric'},
#   {u'id': u'INDKOMKAT_BRUTTO', u'type': u'numeric'},
#   {u'id': u'HUSTANDE', u'type': u'numeric'}],
#  u'records': [{u'AAR': u'2013',
#    u'BYDEL': u'1',
#    u'HUSTANDE': u'249',
#    u'HUSTYP': u'1',
#    u'INDKOMKAT_BRUTTO': u'1',
#    u'_id': 1},
#   {u'AAR': u'2013',
#    u'BYDEL': u'1',
#    u'HUSTANDE': u'17',
#    u'HUSTYP': u'2',
#    u'INDKOMKAT_BRUTTO': u'1',
#    u'_id': 2},
#   {u'AAR': u'2013',
#    u'BYDEL': u'1',
#    u'HUSTANDE': u'30',
#    u'HUSTYP': u'4',
#    u'INDKOMKAT_BRUTTO': u'1',
#    u'_id': 3},
#   {u'AAR': u'2013',
#    u'BYDEL': u'1',
#    u'HUSTANDE': u'4',
# ...
